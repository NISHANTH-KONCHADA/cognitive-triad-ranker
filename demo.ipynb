# %% [markdown]
# # Cognitive Triad Architecture - Sandbox Demo
# This notebook demonstrates our sub-5 minute ranking architecture on a sample of candidates.

# %%
# !git clone https://github.com/sample_user/antigravity-ranker.git
# %cd antigravity-ranker
# !python run_pipeline.py --candidates sample_candidates.json --out sample_submission_output.csv
import pandas as pd
df = pd.read_csv('sample_submission_output.csv')
df.head()
